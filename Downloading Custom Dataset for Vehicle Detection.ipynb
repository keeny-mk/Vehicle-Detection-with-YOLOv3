# %% [markdown]
# In this notebook we attempt to download a subset of images from the famous  Open Images Dataset by Google. We will use OIDv4 toolkit that enables us to specify the classes we wish to download and then convert the annotations style to the darknet format to be ready for YOLOv3 training
#
#
# github repo refrence: https://github.com/theAIGuysCode/OIDv4_ToolKit

# %% [markdown]
# #Clonning OIDv4 toolkit to download our custom object classes training dataset

# %%
# !git clone https://github.com/theAIGuysCode/OIDv4_ToolKit
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 444, done.
# remote: Total 444 (delta 0), reused 0 (delta 0), pack-reused 444
# Receiving objects: 100% (444/444), 34.09 MiB | 29.63 MiB/s, done.
# Resolving deltas: 100% (157/157), done.

# %% [markdown]
# Moving into the toolkit dir and installing the requirements

# %%
# %cd OIDv4_ToolKit/
# !pip install -r requirements.txt
# Out:
# /content/OIDv4_ToolKit
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.21.6)
# Collecting awscli
#   Downloading awscli-1.24.10-py3-none-any.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 5.3 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (4.64.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (4.1.2.30)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: PyYAML<5.5,>=3.10 in /usr/local/lib/python3.7/dist-packages (from awscli->-r requirements.txt (line 3)) (3.13)
# Collecting botocore==1.26.10
#   Downloading botocore-1.26.10-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 36.3 MB/s
# Collecting docutils<0.17,>=0.10
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#      |████████████████████████████████| 548 kB 54.6 MB/s
# Collecting colorama<0.4.5,>=0.2.5
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.0 MB/s
# Collecting rsa<4.8,>=3.1.2
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting urllib3
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 59.3 MB/s
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<4.8,>=3.1.2->awscli->-r requirements.txt (line 3)) (0.4.8)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, rsa, docutils, colorama, awscli
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed awscli-1.24.10 botocore-1.26.10 colorama-0.4.4 docutils-0.16 jmespath-1.0.0 rsa-4.7.2 s3transfer-0.5.2 urllib3-1.26.9

# %%
#we restarted the runtime so we will cd into the toolkit dir again
# %cd OIDv4_ToolKit/
# Out:
# /content/OIDv4_ToolKit

# %% [markdown]
# Then we will run the script that takes in the classes we wish the download as well as the limit of the downloaded images per class
#
# The classes we are interested in for our vehicle detection application are:
# Car, Bus, Van, Truck, Motorcycle and Bicycle

# %%
# !python main.py downloader --classes Car Bus Van Truck Motorcycle Bicycle --type_csv train --limit 1000 --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Car', 'Bus', 'Van', 'Truck', 'Motorcycle', 'Bicycle'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 49782 KB/s, 0 seconds passed
# [DOWNLOAD] | File class-descriptions-boxable.csv downloaded into OID/csv_folder/class-descriptions-boxable.csv.
#    [ERROR] | Missing the train-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 1138 MB, 36296 KB/s, 32 seconds passed
# [DOWNLOAD] | File train-annotations-bbox.csv downloaded into OID/csv_folder/train-annotations-bbox.csv.
#
# Car
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 89465 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | Download of 1000 images in train.
# 100% 1000/1000 [08:45<00:00,  1.90it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Car of train.
#     [INFO] | Labels creation completed.
#
# Bus
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 7293 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | Download of 968 images in train.
# 100% 968/968 [08:36<00:00,  1.87it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bus of train.
#     [INFO] | Labels creation completed.
#
# Van
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 5378 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | Download of 984 images in train.
# 100% 984/984 [09:09<00:00,  1.79it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Van of train.
#     [INFO] | Labels creation completed.
#
# Truck
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 8078 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | Download of 898 images in train.
# 100% 898/898 [08:28<00:00,  1.77it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Truck of train.
#     [INFO] | Labels creation completed.
#
# Motorcycle
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 6944 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | Download of 975 images in train.
# 100% 975/975 [09:23<00:00,  1.73it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Motorcycle of train.
#     [INFO] | Labels creation completed.
#
# Bicycle
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 17631 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | Download of 971 images in train.
# 100% 971/971 [09:23<00:00,  1.72it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bicycle of train.
#     [INFO] | Labels creation completed.

# %% [markdown]
# It can be observed that the number of images for each class (except cars) are less than 1000 (which is the number of images that are supposed to be downloaded per class) and this is because some images were already downloaded before that had multiple object instances so they weren't downloaded again. For example an image with a car and bus was downloaded once in the car class and not downloaded again in the bus class since they are all in the same folder.

# %% [markdown]
# Next step is to convert generated labels to annotations with the format required by Darknet using a ready made script

# %%
# !python convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Car_Bus_Van_Truck_Motorcycle_Bicycle
# 100% 5796/5796 [03:10<00:00, 30.36it/s]

# %% [markdown]
# We will need to delete the old labels folder because we no longer need it

# %%
# !rm -r OID/Dataset/train/Car_Bus_Van_Truck_Motorcycle_Bicycle/Label/

# %% [markdown]
# We will rename the dataset folder into 'obj' so we can refrence it later easily.

# %% [markdown]
# We have now succesfully generated our custom dataset with the proper format that is ready to be trained through the darknet network on the YOLOv3 model

# %% [markdown]
# Finally we will mount our google drive and upload a zipped folder containing the dataset we just downloaded to recall it if the runtime session ended so that we can use it anytime we need

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import zipfile
import os
import sys

zipname = 'obj'

def zipfolder(foldername, target_dir):            
    zipobj = zipfile.ZipFile(foldername + '.zip', 'w', zipfile.ZIP_DEFLATED)
    rootlen = len(target_dir) + 1
    for base, dirs, files in os.walk(target_dir):
        for file in files:
            fn = os.path.join(base, file)
            zipobj.write(fn, fn[rootlen:])

zipfolder(zipname, '/content/OIDv4_ToolKit/OID/Dataset/train')

# %%
# %cp obj.zip /content/gdrive/My\ Drive/yolov3

# %% [markdown]
# #Downloading test dataset using the same method

# %%
# !python main.py downloader --classes Car Bus Van Truck Motorcycle Bicycle --type_csv validation --limit 100 --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Car', 'Bus', 'Van', 'Truck', 'Motorcycle', 'Bicycle'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 37427 KB/s, 0 seconds passed
# [DOWNLOAD] | File class-descriptions-boxable.csv downloaded into OID/csv_folder/class-descriptions-boxable.csv.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 16 MB, 57637 KB/s, 0 seconds passed
# [DOWNLOAD] | File validation-annotations-bbox.csv downloaded into OID/csv_folder/validation-annotations-bbox.csv.
#
# Car
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 4900 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 100 images in validation.
# 100% 100/100 [00:49<00:00,  2.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Car of validation.
#     [INFO] | Labels creation completed.
#
# Bus
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 73 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 73 images in validation.
# 100% 73/73 [00:35<00:00,  2.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bus of validation.
#     [INFO] | Labels creation completed.
#
# Van
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 141 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 94 images in validation.
# 100% 94/94 [00:46<00:00,  2.02it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Van of validation.
#     [INFO] | Labels creation completed.
#
# Truck
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 269 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 91 images in validation.
# 100% 91/91 [00:47<00:00,  1.91it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Truck of validation.
#     [INFO] | Labels creation completed.
#
# Motorcycle
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 128 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 97 images in validation.
# 100% 97/97 [00:48<00:00,  2.00it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Motorcycle of validation.
#     [INFO] | Labels creation completed.
#
# Bicycle
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 242 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 97 images in validation.
# 100% 97/97 [00:48<00:00,  2.02it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bicycle of validation.
#     [INFO] | Labels creation completed.

# %%
# !python convert_annotations.py
# Out:
# Currently in subdirectory: validation
# Converting annotations for class:  Car_Bus_Van_Truck_Motorcycle_Bicycle
# 100% 552/552 [00:12<00:00, 42.62it/s]

# %%
# !rm -r OID/Dataset/validation/Car_Bus_Van_Truck_Motorcycle_Bicycle/Label/

# %%
zipname = 'test'
zipfolder(zipname, '/content/OIDv4_ToolKit/OID/Dataset/validation')

# %%
# %cp test.zip /content/gdrive/My\ Drive/yolov3
